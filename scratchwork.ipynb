# %%
import numpy as np
import pandas as pd
import unicodedata
from rapidfuzz import process, fuzz

df = pd.read_csv("datasets/shots.csv")
df.head(10)
# Out:
#         location                            player  player_id  \
# 0   [94.5, 42.9]                      Aaron Ramsey     3517.0
# 1   [93.5, 48.4]         Francesc Fàbregas i Soler     3478.0
# 2   [89.8, 22.3]  Alexis Alejandro Sánchez Sánchez     3385.0
# 3   [98.2, 26.0]              Diego da Silva Costa     5198.0
# 4  [105.7, 24.2]                      Theo Walcott     3668.0
# 5  [115.1, 45.5]   Pedro Eliezer Rodríguez Ledesma     3958.0
# 6  [103.9, 23.5]                      Aaron Ramsey     3517.0
# 7   [87.3, 42.5]                  Kurt Happy Zouma     3456.0
# 8   [92.6, 47.4]   Pedro Eliezer Rodríguez Ledesma     3958.0
# 9   [95.7, 28.2]         Francesc Fàbregas i Soler     3478.0
#
#                    position  shot_aerial_won  shot_first_time  \
# 0                Right Wing                0                1
# 1  Right Defensive Midfield                0                0
# 2                 Left Wing                0                0
# ...

# %%
df["player"].nunique()
# Out:
# 456

# %%
df["player_id"].nunique()
# Out:
# 452

# %%
preferred_foot = pd.Series(df["player_id"].unique())

preferred_foot.head()
preferred_foot.to_csv("datasets/preferred_foot2.csv", index=False)
